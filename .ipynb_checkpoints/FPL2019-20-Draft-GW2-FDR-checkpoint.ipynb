# %% [markdown]
# # FPL 2019-20 Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %precision 3

# %matplotlib notebook

# %%
df= pd.read_excel("newfpl.xlsx")
df
# Out:
#            name team position  minutes  total_points  bonus  cost
# 0        Aarons  NEW      MID        0             0      0   4.8
# 1       Abraham  CHE      FWD     2206           153     20   7.3
# 2    Adam Smith  CHE      FWD     2055            49      3   4.3
# 3         Adams  SOU      FWD     1095            78      8   5.3
# 4        Adrián  LIV      GKP      873            27      0   4.0
# ..          ...  ...      ...      ...           ...    ...   ...
# 639  Zappacosta  CRY      MID        0             0      0   4.2
# 640  Zimmermann  CRY      MID     1430            35      1   4.4
# 641   Zinchenko  MCI      DEF     1271            49      1   5.2
# 642    Zivkovic  MCI      DEF      107             5      0   4.7
# 643       Zouma  CHE      DEF     2343            62      2   4.7
#
# [644 rows x 7 columns]

# %%
df=df[df["minutes"]> 360]
df
# Out:
#            name team position  minutes  total_points  bonus  cost
# 1       Abraham  CHE      FWD     2206           153     20   7.3
# 2    Adam Smith  CHE      FWD     2055            49      3   4.3
# 3         Adams  SOU      FWD     1095            78      8   5.3
# 4        Adrián  LIV      GKP      873            27      0   4.0
# 6        Agüero  MCI      FWD     1449           132     14  11.6
# ..          ...  ...      ...      ...           ...    ...   ...
# 637    Zabaleta  NEW      DEF      588            10      0   4.1
# 638        Zaha  CRY      MID     3279           120      4   6.6
# 640  Zimmermann  CRY      MID     1430            35      1   4.4
# 641   Zinchenko  MCI      DEF     1271            49      1   5.2
# 643       Zouma  CHE      DEF     2343            62      2   4.7
#
# [401 rows x 7 columns]

# %%
df["ROI"]=df["total_points"]/df["cost"]
# Out:
# <ipython-input-4-82c933d9ece6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ROI"]=df["total_points"]/df["cost"]

# %%
# plt.figure()
df["color"]=None
# plt.scatter(df["total_points"],df["ROI"],df[])
df.head(10)
# Out:
# <ipython-input-5-4a219832c5e0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["color"]=None
#                 name team position  minutes  total_points  bonus  cost  \
# 1            Abraham  CHE      FWD     2206           153     20   7.3
# 2         Adam Smith  CHE      FWD     2055            49      3   4.3
# 3              Adams  SOU      FWD     1095            78      8   5.3
# 4             Adrián  LIV      GKP      873            27      0   4.0
# 6             Agüero  MCI      FWD     1449           132     14  11.6
# 8                Aké  MCI      DEF     2503            79      6   4.8
# 9         Albrighton  LEI      MID      857            38      1   5.1
# 10      Alderweireld  TOT      DEF     2957            97      6   5.3
# 11  Alexander-Arnold  LIV      DEF     3173           210     24   7.7
# 12           Alisson  LIV      GKP     2543           122     11   6.2
#
#           ROI color
# 1   20.958904  None
# 2   11.395349  None
# 3   14.716981  None
# 4    6.750000  None
# 6   11.379310  None
# 8   16.458333  None
# 9    7.450980  None
# 10  18.301887  None
# 11  27.272727  None
# 12  19.677419  None

# %%
df['color'] = np.where((df['position'] == "MID"),
                           "green",df['color'])
df['color'] = np.where((df['position'] == "GKP"),
                           "blue",df['color'])
df['color'] = np.where((df['position'] == "FWD"),
                           "red",df['color'])
df['color'] = np.where((df['position'] == "DEF"),
                           "pink",df['color'])
mids= df[df["position"] == "MID"]
fwds= df[df["position"] == "FWD"]
defs= df[df["position"] == "DEF"]
gks= df[df["position"] == "GKP"]

df.head(10)
# Out:
# <ipython-input-6-fd028469b12e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'] = np.where((df['position'] == "MID"),
# <ipython-input-6-fd028469b12e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'] = np.where((df['position'] == "GKP"),
# <ipython-input-6-fd028469b12e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'] = np.where((df['position'] == "FWD"),
# <ipython-input-6-fd028469b12e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'] = np.where((df['position'] == "DEF"),
#                 name team position  minutes  total_points  bonus  cost  \
# 1            Abraham  CHE      FWD     2206           153     20   7.3
# 2         Adam Smith  CHE      FWD     2055            49      3   4.3
# 3              Adams  SOU      FWD     1095            78      8   5.3
# 4             Adrián  LIV      GKP      873            27      0   4.0
# 6             Agüero  MCI      FWD     1449           132     14  11.6
# 8                Aké  MCI      DEF     2503            79      6   4.8
# 9         Albrighton  LEI      MID      857            38      1   5.1
# 10      Alderweireld  TOT      DEF     2957            97      6   5.3
# 11  Alexander-Arnold  LIV      DEF     3173           210     24   7.7
# 12           Alisson  LIV      GKP     2543           122     11   6.2
#
#           ROI  color
# 1   20.958904    red
# 2   11.395349    red
# 3   14.716981    red
# 4    6.750000   blue
# 6   11.379310    red
# 8   16.458333   pink
# 9    7.450980  green
# 10  18.301887   pink
# 11  27.272727   pink
# 12  19.677419   blue

# %%
import matplotlib.patches as mpatches
plt.figure(figsize=(10,4.8))
# plt.scatter(mids['total_points'], mids["ROI"], color = mids["color"],label= "MID",picker=5,s=17)
# plt.scatter(defs['total_points'], defs["ROI"], color = defs["color"],label= "DEF",picker=5,s=17)
# plt.scatter(fwds['total_points'], fwds["ROI"], color = fwds["color"],label= "FWD",picker=5,s=17)
# plt.scatter(gks['total_points'], gks["ROI"], color = gks["color"],label= "GK",picker=5,s=17)
plt.scatter(df['total_points'], df["ROI"], color = df["color"],picker=5,s=17)



red_patch = mpatches.Patch(color='red', label='FWD')
blue_patch = mpatches.Patch(color='blue', label='GKP')
green_patch = mpatches.Patch(color='green', label='MID')
pink_patch = mpatches.Patch(color='pink', label='DEF')
plt.legend(loc=4,prop={'size': 12, "family":"Arial"},handles=[red_patch,blue_patch,green_patch,pink_patch])

# total_points=(df[df["position"]=="MID"])["total_points"].tolist()
# ROI=df["ROI"].tolist()
# name=df["name"].tolist()


# fig = plt.gcf()
# size = fig.get_size_inches()*(fig.dpi)
# print(size,fig.dpi)
# Out:
# <img src="data:image/png;base64,..." width="999.68">

# %%
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.title("Points per million v/s Total Points for all players across 2019-20 Fantasy Premier League")
plt.xlabel("Total Points")
plt.ylabel("Points per million")

# plt.legend(loc=4,prop={'size': 12, "family":"Arial"},markerscale=2)
# plt.rc('legend',**{'fontsize':18})
# plt.rcParams['legend.title_fontsize'] = 'large'
ax.grid(True)

# ax.legend(markerscale=2)
# plt.rcParams.keys()

# %%
def onpick(event):
    
    name = df.iloc[event.ind[0]]['name']
    roi  = df.iloc[event.ind[0]]["ROI"]
    tota = df.iloc[event.ind[0]]["total_points"]
    plt.gca().set_title('{} ({},{})'.format(name,tota,roi))
    
# tell mpl_connect we want to pass a 'pick_event' into onpick when the event is detected
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7

# %%
anss= df["ROI"].mean()
anss
# Out:
# 13.633

# %%
for item,frame in df[df["ROI"] >= anss].groupby("team"):
    print("{} players of {} have ROI greater than the global average".format(len(frame),frame["team"].unique()))
# Out:
# 8 players of ['ARS'] have ROI greater than the global average
# 10 players of ['AVL'] have ROI greater than the global average
# 10 players of ['BHA'] have ROI greater than the global average
# 11 players of ['BUR'] have ROI greater than the global average
# 7 players of ['CHE'] have ROI greater than the global average
# 9 players of ['CRY'] have ROI greater than the global average
# 10 players of ['EVE'] have ROI greater than the global average
# 4 players of ['FUL'] have ROI greater than the global average
# 1 players of ['LEE'] have ROI greater than the global average
# 14 players of ['LEI'] have ROI greater than the global average
# 13 players of ['LIV'] have ROI greater than the global average
# 12 players of ['MCI'] have ROI greater than the global average
# 10 players of ['MUN'] have ROI greater than the global average
# 11 players of ['NEW'] have ROI greater than the global average
# 12 players of ['SHU'] have ROI greater than the global average
# 10 players of ['SOU'] have ROI greater than the global average
# 11 players of ['TOT'] have ROI greater than the global average
# 1 players of ['WBA'] have ROI greater than the global average
# 11 players of ['WHU'] have ROI greater than the global average
# 14 players of ['WOL'] have ROI greater than the global average

# %%
sum_ROI= df["ROI"].sum()
sum_ROI
# Out:
# 5466.86303744802

# %%
#TOP 25 % AVERAGE

new_df=df.sort_values(by=["ROI"],ascending=False)

for item,frame in new_df.head(int(len(df)/4)).groupby("team"):
    print("{} players of {} have ROI greater than the 75% players".format(len(frame),frame["team"].iloc[0]))
# Out:
# 3 players of ARS have ROI greater than the 75% players
# 4 players of AVL have ROI greater than the 75% players
# 5 players of BHA have ROI greater than the 75% players
# 7 players of BUR have ROI greater than the 75% players
# 5 players of CHE have ROI greater than the 75% players
# 3 players of CRY have ROI greater than the 75% players
# 6 players of EVE have ROI greater than the 75% players
# 10 players of LEI have ROI greater than the 75% players
# 7 players of LIV have ROI greater than the 75% players
# 5 players of MCI have ROI greater than the 75% players
# 8 players of MUN have ROI greater than the 75% players
# 4 players of NEW have ROI greater than the 75% players
# 10 players of SHU have ROI greater than the 75% players
# 7 players of SOU have ROI greater than the 75% players
# 3 players of TOT have ROI greater than the 75% players
# 2 players of WHU have ROI greater than the 75% players
# 11 players of WOL have ROI greater than the 75% players

# %%
# top 10%
# df.sort_values(by=["ROI"],inplace=True,ascending=False)

for item,frame in new_df.head(int(len(df)/10)).groupby("team"):
    print("{} players of {} have ROI greater than the 90% players".format(len(frame),frame["team"].iloc[0]))
# Out:
# 2 players of ARS have ROI greater than the 90% players
# 1 players of AVL have ROI greater than the 90% players
# 2 players of BHA have ROI greater than the 90% players
# 2 players of BUR have ROI greater than the 90% players
# 2 players of CRY have ROI greater than the 90% players
# 3 players of LEI have ROI greater than the 90% players
# 3 players of LIV have ROI greater than the 90% players
# 2 players of MCI have ROI greater than the 90% players
# 5 players of MUN have ROI greater than the 90% players
# 2 players of NEW have ROI greater than the 90% players
# 7 players of SHU have ROI greater than the 90% players
# 3 players of SOU have ROI greater than the 90% players
# 2 players of TOT have ROI greater than the 90% players
# 4 players of WOL have ROI greater than the 90% players

# %% [markdown]
# # Knapsacking the Best initial team

# %%
knapsackdf1 = df.copy(deep=True)
knapsackdf1
# Out:
#            name team position  minutes  total_points  bonus  cost        ROI  \
# 1       Abraham  CHE      FWD     2206           153     20   7.3  20.958904
# 2    Adam Smith  CHE      FWD     2055            49      3   4.3  11.395349
# 3         Adams  SOU      FWD     1095            78      8   5.3  14.716981
# 4        Adrián  LIV      GKP      873            27      0   4.0   6.750000
# 6        Agüero  MCI      FWD     1449           132     14  11.6  11.379310
# ..          ...  ...      ...      ...           ...    ...   ...        ...
# 637    Zabaleta  NEW      DEF      588            10      0   4.1   2.439024
# 638        Zaha  CRY      MID     3279           120      4   6.6  18.181818
# 640  Zimmermann  CRY      MID     1430            35      1   4.4   7.954545
# 641   Zinchenko  MCI      DEF     1271            49      1   5.2   9.423077
# 643       Zouma  CHE      DEF     2343            62      2   4.7  13.191489
#
#      color
# 1      red
# 2      red
# 3      red
# 4     blue
# 6      red
# ..     ...
# 637   pink
# 638  green
# 640  green
# 641   pink
# 643   pink
#
# [401 rows x 9 columns]

# %%
knapsackdf2 = df.copy(deep=True)
knapsackdf2
# Out:
#            name team position  minutes  total_points  bonus  cost        ROI  \
# 1       Abraham  CHE      FWD     2206           153     20   7.3  20.958904
# 2    Adam Smith  CHE      FWD     2055            49      3   4.3  11.395349
# 3         Adams  SOU      FWD     1095            78      8   5.3  14.716981
# 4        Adrián  LIV      GKP      873            27      0   4.0   6.750000
# 6        Agüero  MCI      FWD     1449           132     14  11.6  11.379310
# ..          ...  ...      ...      ...           ...    ...   ...        ...
# 637    Zabaleta  NEW      DEF      588            10      0   4.1   2.439024
# 638        Zaha  CRY      MID     3279           120      4   6.6  18.181818
# 640  Zimmermann  CRY      MID     1430            35      1   4.4   7.954545
# 641   Zinchenko  MCI      DEF     1271            49      1   5.2   9.423077
# 643       Zouma  CHE      DEF     2343            62      2   4.7  13.191489
#
#      color
# 1      red
# 2      red
# 3      red
# 4     blue
# 6      red
# ..     ...
# 637   pink
# 638  green
# 640  green
# 641   pink
# 643   pink
#
# [401 rows x 9 columns]

# %%
knapsackdf1= knapsackdf1.sort_values(by="total_points",ascending= False)
((knapsackdf1[knapsackdf1["name"] == "De Bruyne"])).iloc[0]["name"]
# Out:
# 'De Bruyne'

# %%
knapsackdf2= knapsackdf2.sort_values(by="ROI",ascending= False)
knapsackdf2
# Out:
#           name team position  minutes  total_points  bonus  cost        ROI  \
# 475       Pope  BUR      GKP     3420           170     23   5.2  32.692308
# 366  Lundstram  SHU      MID     2452           144     15   4.6  31.304348
# 256  Henderson  MUN      GKP     3240           160     16   5.2  30.769231
# 459   Patrício  WOL      GKP     3420           153      8   5.3  28.867925
# 509       Ryan  BHA      GKP     3420           135     14   4.7  28.723404
# ..         ...  ...      ...      ...           ...    ...   ...        ...
# 637   Zabaleta  NEW      DEF      588            10      0   4.1   2.439024
# 25    Angeliño  EVE      MID      422            11      1   4.6   2.391304
# 513      Sakho  CRY      DEF      929            11      0   5.0   2.200000
# 322      Klose  LEE      MID      585             9      0   4.3   2.093023
# 438     Ngakia  WOL      MID      440             8      0   4.0   2.000000
#
#      color
# 475   blue
# 366  green
# 256   blue
# 459   blue
# 509   blue
# ..     ...
# 637   pink
# 25   green
# 513   pink
# 322  green
# 438  green
#
# [401 rows x 9 columns]

# %%
gw_initial  = pd.read_csv("cleaned_players.csv")
gw_initial["now_cost"] = gw_initial["now_cost"] / 10
gw_initial = gw_initial[["first_name","second_name","now_cost"]]
gw_initial
# Out:
#          first_name           second_name  now_cost
# 0             Mesut                  Özil       7.0
# 1          Sokratis      Papastathopoulos       5.0
# 2             David  Luiz Moreira Marinho       5.5
# 3    Pierre-Emerick            Aubameyang      12.0
# 4            Cédric                Soares       5.0
# ..              ...                   ...       ...
# 524     Bruno André         Cavaco Jordao       4.5
# 525        Leonardo               Campana       5.0
# 526           Fabio                 Silva       5.5
# 527        Fernando                Marçal       5.0
# 528           Vitor              Ferreira       5.0
#
# [529 rows x 3 columns]

# %%
injured_list_initial = pd.read_excel('Injured list GW1.xlsx')
injured_list_initial.drop("id",axis = 1,inplace = True)
injured_list_initial = injured_list_initial[["Name","Team","Position","Availability","Chance to Play"]]
injured_list_initial.fillna(0,inplace=True)
injured_list_initial
# Out:
#          Name Team Position Availability  Chance to Play
# 0       Ajeti  WHU      FWD     NotAvail             0.0
# 1      Andone  BHA      FWD      Injured             0.0
# 2   Armstrong  SOU      MID      Injured             0.0
# 3      Barnes  BUR      FWD      Injured             0.0
# 4    Benkovic  LEI      DEF      Injured             0.0
# ..        ...  ...      ...          ...             ...
# 76    Wickham  CRY      FWD      Injured             0.0
# 77   Wilshere  WHU      MID     Doubtful             0.0
# 78      Woods  CRY      DEF     Doubtful             0.0
# 79     Ziyech  CHE      MID      Injured             0.0
# 80     Zohore  WBA      FWD      Injured             0.0
#
# [81 rows x 5 columns]

# %% [markdown]
# # Constraints
# 1. Maximum 3 Players per team
# 2. Number of Players by respective position :-
# a) GK - 2
# b) DEF - 5
# c) MID - 5
# a) FWD - 3
# 3. And the main one
# BUDGET - $100 M

# %%
def select_players(gk = 2, defe = 5, mid =5,fwd =0, moneytotal = 80.5):
    exp_players = 2
    total_points = 0
    roi = 0
    fdr_init = [
2.666666667,
2.666666667,
2.666666667,
2.666666667,
3.333333333,
2.666666667,
4,
3.666666667,
2.666666667,
2.666666667,
3,
3.333333333,
3.666666667,
3,
3,
3.333333333,
3.333333333,
3.333333333,
2.333333333,
3.333333333
]


    positions = { "GKP" : gk , "MID" : mid , "DEF" : defe, "FWD" : fwd}
    strteam = "ARS AVL BHA BUR CHE CRY EVE FUL LEE LEI LIV MCI MUN NEW SHU SOU TOT WBA WHU WOL"
    init_diff= {}
    strteam= strteam.split()
    team_limit = {}
    for i in range(len(strteam)):
        init_diff[strteam[i]] = fdr_init[i]
    for item in strteam:
        team_limit[item] = 3 #2
#     team_limit["LIV"] = 3
#     team_limit["SOU"] = 1
    # teams = { "" : }
    final_team = []
    count_players = 0
    roi_players = 10
    print(moneytotal)
    cummulative_cost = 0
    liscost = []
    names_only = []
    #players i dont want
    details = [("Henderson","MUN") , ("Aurier","TOT"),("James","MUN"), ("de Gea","MUN"),("Fernández","TOT"),("Shelvey","NEW")
              ,('Dendoncker',"WOL")]
    # Taking star players
    for idx,r in knapsackdf1.iterrows():
        if exp_players==0:
            break
        else:
            nm = r["name"]
            clb = r["team"]
            pos = r["position"]
            
            if (nm,clb) in details:
                continue
            if clb not in strteam:
                continue
            if init_diff[clb]<=2.7:
                continue
            if nm in gw_initial.values and (nm,clb) not in names_only:
                if nm not in injured_list_initial.values or ((len(injured_list_initial[injured_list_initial["Name"] == nm] > 0)
                                                             and (injured_list_initial[injured_list_initial["Name"] == nm]["Chance to Play"].values > 70))):
                    
                    cst =( gw_initial[(gw_initial["second_name"] == nm )|( gw_initial["first_name"] == nm )]["now_cost"].values)[0]
                    
                    if(positions[pos]) > 0 and (team_limit[clb] > 0 and moneytotal>=cst):
                        names_only.append((nm,clb))
                        total_points = total_points + r["total_points"]
                        final_team.append((nm,pos,cst,clb,r["total_points"],r["ROI"]))
                        roi =  roi + r["ROI"]
                        moneytotal = moneytotal - cst
                        exp_players = exp_players -1
                        positions[pos] = positions[pos] - 1
                        team_limit[clb] = team_limit[clb] -1
                        cummulative_cost = cummulative_cost + cst 
                        liscost.append(cummulative_cost)

    for idx,r in knapsackdf2.iterrows():
        if roi_players < 0:
            break;
        else:
            nm = r["name"]
            clb = r["team"]
            pos = r["position"]
            
            if clb not in strteam:
                continue
            if (nm,clb) in details:
                continue
            if init_diff[clb]<=2.7:
                continue
            if nm in gw_initial.values and (nm,clb) not in names_only:
                if nm not in injured_list_initial.values or ((len(injured_list_initial[injured_list_initial["Name"] == nm]) > 0)
                                                             and ((injured_list_initial[injured_list_initial["Name"] == nm]["Chance to Play"].values) > 70)):
                   
                    cst =( gw_initial[(gw_initial["second_name"] == nm )|( gw_initial["first_name"] == nm )]["now_cost"].values)[0]
                    if(nm == "Long" and clb == "SOU"):
                        cst = 5.5
                    curcst = moneytotal - cst
                    curplay = (roi_players -1) * 4.9
                    if(positions[pos]) > 0 and (team_limit[clb] > 0) and (moneytotal>=cst) and (curcst >= curplay):
                        names_only.append((nm,clb))
                        total_points = total_points + r["total_points"]
                        final_team.append((nm,pos,cst,clb,r["total_points"],r["ROI"]))
                        roi =  roi + r["ROI"]
                        moneytotal = moneytotal - cst
                        roi_players = roi_players -1
                        positions[pos] = positions[pos] - 1
                        team_limit[clb] = team_limit[clb] -1
                        cummulative_cost = cummulative_cost + cst 
                        liscost.append(cummulative_cost)
#     print(len(final_team))
#     print(final_team)
#     print("last year ", total_points)
#     print(moneytotal)
#     print(roi)
    print(liscost)
    print(positions)
    str1 = knapsackdf2[knapsackdf2["name"] == "Wilson"].values
    str2= knapsackdf2[(knapsackdf2["name"] == "Adams") & (knapsackdf2["position"] == "FWD")].values
    str3= knapsackdf2[(knapsackdf2["name"] == "Calvert-Lewin") & (knapsackdf2["position"] == "FWD")].values
    print((str3.tolist())[0])
#     final_team.append((str1.iloc[0]["name"],str1.iloc[0]["position"], str1.iloc[0]["cost"],str1.iloc[0]["team"],str1.iloc[0]["total_points"],str1.iloc[0]["ROI"]))
#     final_team.append((str2.iloc[0]["name"],str2.iloc[0]["position"], str2.iloc[0]["cost"],str2.iloc[0]["team"],str2.iloc[0]["total_points"],str2.iloc[0]["ROI"]))
#     final_team.append((str3.iloc[0]["name"],str3.iloc[0]["position"], str3.iloc[0]["cost"],str3.iloc[0]["team"],str3.iloc[0]["total_points"],str3.iloc[0]["ROI"]))    
    return final_team
select_players()
# Out:
# 80.5
# [11.5, 23.5, 29.0, 34.0, 39.5, 46.0, 53.5, 59.5, 65.0, 69.5, 75.0, 80.5]
# {'GKP': 0, 'MID': 0, 'DEF': 0, 'FWD': 0}
# ['Calvert-Lewin', 'EVE', 'FWD', 2621, 126, 15, 6.1, 20.655737704918035, 'red']
# [('De Bruyne', 'MID', 11.5, 'MCI', 251, 23.679),
#  ('Salah', 'MID', 12.0, 'LIV', 233, 18.640),
#  ('Lundstram', 'MID', 5.5, 'SHU', 144, 31.304),
#  ('Ramsdale', 'GKP', 5.0, 'SHU', 126, 28.636),
#  ('Baldock', 'DEF', 5.5, 'SHU', 142, 28.400),
#  ('van Dijk', 'DEF', 6.5, 'LIV', 178, 27.385),
#  ('Alexander-Arnold', 'DEF', 7.5, 'LIV', 210, 27.273),
#  ('Doherty', 'DEF', 6.0, 'TOT', 167, 25.692),
#  ('Maguire', 'DEF', 5.5, 'MUN', 123, 23.208),
#  ('McCarthy', 'GKP', 4.5, 'SOU', 104, 23.111),
#  ('Doucouré', 'MID', 5.5, 'EVE', 113, 20.926),
#  ('Saint-Maximin', 'MID', 5.5, 'NEW', 92, 17.692)]

# %%
def gw1():
    x = select_players()
    myGW1choice = pd.DataFrame(x,columns= ["name","position","cost","team","total_ls","roi_ls"])
    return myGW1choice
gw1()
# Out:
# 80.5
# [11.5, 23.5, 29.0, 34.0, 39.5, 46.0, 53.5, 59.5, 65.0, 69.5, 75.0, 80.5]
# {'GKP': 0, 'MID': 0, 'DEF': 0, 'FWD': 0}
#                 name position  cost team  total_ls     roi_ls
# 0          De Bruyne      MID  11.5  MCI       251  23.679245
# 1              Salah      MID  12.0  LIV       233  18.640000
# 2          Lundstram      MID   5.5  SHU       144  31.304348
# 3           Ramsdale      GKP   5.0  SHU       126  28.636364
# 4            Baldock      DEF   5.5  SHU       142  28.400000
# 5           van Dijk      DEF   6.5  LIV       178  27.384615
# 6   Alexander-Arnold      DEF   7.5  LIV       210  27.272727
# 7            Doherty      DEF   6.0  TOT       167  25.692308
# 8            Maguire      DEF   5.5  MUN       123  23.207547
# 9           McCarthy      GKP   4.5  SOU       104  23.111111
# 10          Doucouré      MID   5.5  EVE       113  20.925926
# 11     Saint-Maximin      MID   5.5  NEW        92  17.692308

# %%
# dir(pd.DataFrame)
gw1team =gw1()
gw1team.to_csv("My_GW1.csv")
# Out:
# 80.5
# [11.5, 23.5, 29.0, 34.0, 39.5, 46.0, 53.5, 59.5, 65.0, 69.5, 75.0, 80.5]
# {'GKP': 0, 'MID': 0, 'DEF': 0, 'FWD': 0}
